# %% [markdown]
# <a href="https://colab.research.google.com/github/mic006016/python_data/blob/main/test01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome");
# Out:
# welcome

# %%
print('화요일이닷');
# Out:
# 화요일이닷

# %%
# 아래 셀을 만들고, 실행하는 결과도 보여줘
# shift + enter

# %%
food = input("먹고 싶은 음식은");
food # 변수명만 쓰면 input(food)
# Out:
# 먹고 싶은 음식은 치킨
# '치킨'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
